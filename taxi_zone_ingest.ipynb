# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
df_zones=pd.read_csv(r'D:\Ahmed\taxi_zone_lookup.csv')
df_zones.head()
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
pg_user ='root'
pg_password='root'
pg_host='localhost'
pg_port=5432
pg_db='ny_taxi'
engine=create_engine(f'postgresql://{pg_user}:{pg_password}@{pg_host}:{pg_port}/{pg_db}')

# %%
df_zones.to_sql(name='zones',con=engine,if_exists='replace')
# Out:
# 265

# %%
df_greentrips=pd.read_parquet("D:\Ahmed\green_tripdata_2025-11.parquet")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# C:\Users\asus\AppData\Local\Temp\ipykernel_30676\3795804847.py:1: SyntaxWarning: invalid escape sequence '\A'
#   df_greentrips=pd.read_parquet("D:\Ahmed\green_tripdata_2025-11.parquet")

# %%
df_greentrips.to_sql(name='green_taxi_trips',con=engine,if_exists='replace')
# Out:
# 912
